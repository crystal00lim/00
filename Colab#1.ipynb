# %% [markdown]
# <a href="https://colab.research.google.com/github/crystal00lim/00/blob/master/Colab%231.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
salary = 25
shiftLength = 5
shift = 5
PayPerWeek = salary * shift * shiftLength
print(PayPerWeek)
PayPerMonth = PayPerWeek * 4
print(PayPerMonth)
PayPerYear = PayPerMonth * 12
print(PayPerYear)
# Out:
# 625
# 2500
# 30000

# %% [markdown]
# Unable to download upsetplot package from Python

# %%
import os
from matplotlib import pyplot
import pandas as pd
import openpyxl

# %%
List = [2, 3, 4, 4, 5, 1, 6, 8, 9, 10]
list2 = [6, 7, 8, 9, 2, 3, 6, 7, 4, 1]
List3 = ["nancy", "george", "bob", "david", "mark", "angel", "diana", "amber", "crystal", "john"]
dataframe = {"Name" : List3,
             "Lucky #" : List,
             "# of Friends" : list2}
df = pd.DataFrame(dataframe)
df.head()
# Out:
#      Name  Lucky #  # of Friends
# 0   nancy        2             6
# 1  george        3             7
# 2     bob        4             8
# 3   david        4             9
# 4    mark        5             2
